# %% [markdown]
# # ❤️ Heart Disease Prediction Project
#
# ### Task Instructions:
# - ✅ Clean the dataset (handle missing values if any)
# - ✅ Perform Exploratory Data Analysis (EDA)
# - ✅ Train a classification model (Logistic Regression or Decision Tree)
# - ✅ Evaluate the model using accuracy, ROC curve, and confusion matrix
# - ✅ Highlight important features affecting prediction

# %%
# Import libraries and custom modules
import pandas as pd
from heart_disease_predictor import load_data, preprocess_data, train_model, evaluate_model, display_feature_importance
from eda_visuals import plot_class_distribution, plot_correlation_heatmap

# %%
# Load data
df = load_data(r"C:\Users\AAFIA\Desktop\heart_disease_prediction\Heart_disease_cleveland_new.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   0       145   233    1        2      150      0      2.3      2
# 1   67    1   3       160   286    0        2      108      1      1.5      1
# 2   67    1   3       120   229    0        2      129      1      2.6      1
# 3   37    1   2       130   250    0        0      187      0      3.5      2
# 4   41    0   1       130   204    0        2      172      0      1.4      0
#
#    ca  thal  target
# 0   0     2       0
# 1   3     1       1
# 2   2     3       1
# 3   0     1       0
# 4   0     1       0

# %%
# Clean the dataset: handle missing values
def clean_dataset(df):
    print("🔍 Missing values in each column:")
    print(df.isnull().sum())
    print("\n✅ Total missing values:", df.isnull().sum().sum())
    df_clean = df.dropna()
    print(f"\n🧹 Cleaned dataset shape: {df_clean.shape}")
    return df_clean

df = clean_dataset(df)
# Out:
# 🔍 Missing values in each column:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64
#
# ✅ Total missing values: 0
#
# 🧹 Cleaned dataset shape: (303, 14)

# %%
# EDA: Plot class distribution
plot_class_distribution(df)

# %%
# EDA: Correlation heatmap
plot_correlation_heatmap(df)

# %%
# Preprocess data for training
X_train, X_test, y_train, y_test, scaler = preprocess_data(df)

# %%
# Train classification model (logistic or decision tree)
model = train_model(X_train, y_train, model_type='logistic')  # Change to 'tree' if needed

# %%
# Evaluate the model
evaluate_model(model, X_test, y_test)
# Out:
# Accuracy: 0.89
# ROC-AUC Score: 0.92
# Confusion Matrix:
# [[25  4]
#  [ 3 29]]

# %%
# Show feature importance
display_feature_importance(model, df.columns[:-1])
